# %%
import requests
import time
import pandas as pd
from typing import Optional, Dict, List
from id_converter import url_id_to_numeric, numeric_to_url_id
"""
Fetch raw event data from the API.

Returns:
    dict if valid event
    None if invalid / not found / error
"""
event_id = 41091
timeout = 10

str_event_id = numeric_to_url_id(event_id)
url = f"https://results.advancedeventsystems.com/api/event/{str_event_id}"
print(url)

response = requests.get(url, timeout=timeout)
print(response.status_code)
data = response.json()
print(data)
# Out:
# https://results.advancedeventsystems.com/api/event/PTAwMDAwNDEwOTE90
# 200
# {'Key': 'PTAwMDAwNDEwOTE90', 'EventId': 41091, 'Name': '2026 AAU Rocky Mount Grand Prix and Boys ECPL', 'StartDate': '2026-04-18T00:00:00', 'EndDate': '2026-04-19T23:59:59.9999999', 'Location': ' Rocky Mount  Events Center', 'CustomEventType': None, 'IsOver': True, 'Clubs': [{'ClubId': 32710, 'Name': '495 Legacy Volleyball, Inc'}, {'ClubId': 14541, 'Name': 'Active Volleyball Club'}, {'ClubId': 18629, 'Name': 'Albemarle Regional Volleyball Club'}, {'ClubId': 31017, 'Name': 'Apex'}, {'ClubId': 24856, 'Name': 'Appalachian Volleyball Club'}, {'ClubId': 24416, 'Name': 'Battle Volleyball Club'}, {'ClubId': 27418, 'Name': 'Carolina Performance Volleyball Club'}, {'ClubId': 32545, 'Name': 'Carolina Vibe Volleyball Club'}, {'ClubId': 33046, 'Name': 'CAVB Club'}, {'ClubId': 4571, 'Name': 'Champion Volleyball Club'}, {'ClubId': 32583, 'Name': 'Club Boom'}, {'ClubId': 30190, 'Name': 'Coastal Cities Volleyball Club'}, {'ClubId': 31150, 'Name': 'Coastline Volleyball Club, Inc.'}, {'ClubId': 31104, 'Name': 'Eclipse Volleyball Club'}, {'ClubId': 23449, 'Name': 'Edge Volleyball Virginia'}, {'ClubId': 26546, 'Name': 'FC Firecrackers Volleyball Club'}, {'ClubId': 28507, 'Name': 'Five-Four-Zero Volleyball Academy'}, {'ClubId': 32808, 'Name': 'Level Up Volleyball Club'}, {'ClubId': 20943, 'Name': 'Monument Volleyball'}, {'ClubId': 14552, 'Name': 'NC Coastal Volleyball'}, {'ClubId': 66, 'Name': 'NC Elite Volleyball Club'}, {'ClubId': 25943, 'Name': 'NC Intensity Volleyball Club'}, {'ClubId': 31442, 'Name': 'Norfolk Volleyball Club'}, {'ClubId': 27747, 'Name': 'Northern Piedmont Sports Club'}, {'ClubId': 4466, 'Name': 'Ocean Volleyball Club'}, {'ClubId': 14420, 'Name': 'Outbreak Volleyball Club'}, {'ClubId': 11453, 'Name': 'Palmetto Rage Volleyball Club'}, {'ClubId': 31670, 'Name': 'Palmetto Shore Volleyball'}, {'ClubId': 14494, 'Name': 'Palmetto Strikers Volleyball Club'}, {'ClubId': 476, 'Name': 'Piedmont Volleyball Club'}, {'ClubId': 366, 'Name': 'Richmond Volleyball Club'}, {'ClubId': 24446, 'Name': 'River City Volleyball Academy'}, {'ClubId': 27623, 'Name': 'Rockville Volleyball Academy'}, {'ClubId': 8820, 'Name': 'South East Region Volleyball'}, {'ClubId': 23613, 'Name': 'The St. James Volleyball Club'}, {'ClubId': 11959, 'Name': 'Tidewater Volleyball'}, {'ClubId': 26637, 'Name': 'Top Caliber Volleyball Club'}, {'ClubId': 1, 'Name': 'Triangle Volleyball Club'}, {'ClubId': 32584, 'Name': 'United Sports Alliance'}, {'ClubId': 28887, 'Name': 'VIBE Volleyball Club'}, {'ClubId': 29799, 'Name': 'Virginia Wave Volleyball'}, {'ClubId': 30688, 'Name': 'Volei'}, {'ClubId': 26785, 'Name': 'VolleyViet Volleyball Club'}], 'Divisions': [{'IsFinished': True, 'DivisionId': 194042, 'Name': '14 Boys', 'TeamCount': 7, 'CodeAlias': '14 Boys', 'ColorHex': '#5FDFDF'}, {'IsFinished': True, 'DivisionId': 194045, 'Name': '14 Club', 'TeamCount': 17, 'CodeAlias': '14 C', 'ColorHex': '#7F9FFF'}, {'IsFinished': True, 'DivisionId': 194041, 'Name': '15 Club', 'TeamCount': 13, 'CodeAlias': '15C', 'ColorHex': '#FF7F9F'}, {'IsFinished': True, 'DivisionId': 194044, 'Name': '16 Boys Open', 'TeamCount': 8, 'CodeAlias': '16 BO', 'ColorHex': '#FFDF7F'}, {'IsFinished': True, 'DivisionId': 194038, 'Name': '16 Boys Premier', 'TeamCount': 20, 'CodeAlias': '16 BP', 'ColorHex': '#5FDF9F'}, {'IsFinished': True, 'DivisionId': 194036, 'Name': '16 Club', 'TeamCount': 16, 'CodeAlias': '16C', 'ColorHex': '#FF5FDF'}, {'IsFinished': True, 'DivisionId': 194043, 'Name': '18 Boys Open', 'TeamCount': 7, 'CodeAlias': '18 BO', 'ColorHex': '#FF5F5F'}, {'IsFinished': True, 'DivisionId': 194039, 'Name': '18 Boys Premier', 'TeamCount': 26, 'CodeAlias': '18 BP', 'ColorHex': '#9F5FFF'}, {'IsFinished': True, 'DivisionId': 194037, 'Name': '18 Club', 'TeamCount': 10, 'CodeAlias': '18C', 'ColorHex': '#FF5FDF'}], 'HasNotes': False, 'HasFlowCharts': False, 'IsUsavQualifierEvent': False}
