# %%
import requests
import time
import pandas as pd
import json
from pathlib import Path
from typing import Optional, Dict, List
from id_converter import url_id_to_numeric, numeric_to_url_id

# %%
def fetch_event(event_id: int, timeout: int = 10) -> Optional[dict]:
    str_event_id = numeric_to_url_id(event_id)
    url = f"https://results.advancedeventsystems.com/api/event/{str_event_id}"
    
    try:
        response = requests.get(url, timeout=timeout)
        
        if response.status_code != 200:
            return None
        
        data = response.json()
        
        if not data or 'EventId' not in data:
            return None
        
        return data
    
    except requests.RequestException:
        return None

# %%
def save_event_json(data: dict, base_path: str = "data/raw/events") -> None:
    """
    Save raw event JSON to disk using event_id as filename.
    """
    event_id = data.get("EventId")
    
    if not event_id:
        return
    
    # Ensure directory exists
    Path(base_path).mkdir(parents=True, exist_ok=True)
    
    file_path = Path(base_path) / f"event_{event_id}.json"
    
    with open(file_path, "w") as f:
        json.dump(data, f, indent=2)

# %%
def fetch_and_save_event(event_id: int) -> Optional[dict]:
    data = fetch_event(event_id)
    
    if data:
        save_event_json(data)
    
    return data

# %%
for event_id in range(40982, 44444):
    print(f"Processing {event_id}...")
    
    data = fetch_and_save_event(event_id)
    
    if data is None:
        print(f"Event {event_id} not found")
# Out:
# Processing 40982...
# Processing 40983...
# Processing 40984...
# Processing 40985...
# Processing 40986...
# Processing 40987...
# Event 40987 not found
# Processing 40988...
# Processing 40989...
# Processing 40990...
# Processing 40991...
# Processing 40992...
# Processing 40993...
# Processing 40994...
# Processing 40995...
# Processing 40996...
# Processing 40997...
# Processing 40998...
# Processing 40999...
# Processing 41000...
# Processing 41001...
# Event 41001 not found
# Processing 41002...
# Processing 41003...
# Processing 41004...
# Processing 41005...
# Event 41005 not found
# Processing 41006...
# Processing 41007...
# Processing 41008...
# Processing 41009...
# Processing 41010...
# Processing 41011...
# Processing 41012...
# Event 41012 not found
# Processing 41013...
# Processing 41014...
# Event 41014 not found
# Processing 41015...
# Event 41015 not found
# Processing 41016...
# Event 41016 not found
# Processing 41017...
# Processing 41018...
# Processing 41019...
# Processing 41020...
# Processing 41021...
# Event 41021 not found
# Processing 41022...
# Event 41022 not found
# Processing 41023...
# Processing 41024...
# Processing 41025...
# Processing 41026...
# Processing 41027...
# Processing 41028...
# Processing 41029...
# Event 41029 not found
# Processing 41030...
# Processing 41031...
# Processing 41032...
# Event 41032 not found
# Processing 41033...
# Event 41033 not found
# Processing 41034...
# Event 41034 not found
# Processing 41035...
# Event 41035 not found
# Processing 41036...
# Processing 41037...
# Processing 41038...
# Processing 41039...
# Event 41039 not found
# Processing 41040...
# Processing 41041...
# Processing 41042...
# Processing 41043...
# Processing 41044...
# Processing 41045...
# Processing 41046...
# Processing 41047...
# Event 41047 not found
# Processing 41048...
# Processing 41049...
# Processing 41050...
# Processing 41051...
# Processing 41052...
# Processing 41053...
# Processing 41054...
# Processing 41055...
# Processing 41056...
# Event 41056 not found
# Processing 41057...
# Event 41057 not found
# Processing 41058...
# Processing 41059...
# Processing 41060...
# Processing 41061...
# Processing 41062...
# Event 41062 not found
# Processing 41063...
# Processing 41064...
# Processing 41065...
# Processing 41066...
# Processing 41067...
# Processing 41068...
# Processing 41069...
# Event 41069 not found
# Processing 41070...
# Processing 41071...
# Processing 41072...
# Processing 41073...
# Processing 41074...
# Processing 41075...
# Processing 41076...
# Processing 41077...
# Processing 41078...
# Processing 41079...
# Event 41079 not found
# Processing 41080...
# Event 41080 not found
# Processing 41081...
# Event 41081 not found
# Processing 41082...
# Event 41082 not found
# Processing 41083...
# Event 41083 not found
# Processing 41084...
# Processing 41085...
# Processing 41086...
# Processing 41087...
# Processing 41088...
# Processing 41089...
# Processing 41090...
# Processing 41091...
# Processing 41092...
# Event 41092 not found
# Processing 41093...
# Processing 41094...
# Processing 41095...
# Processing 41096...
# Processing 41097...
# Processing 41098...
# Event 41098 not found
# Processing 41099...
# Event 41099 not found
# Processing 41100...
# Processing 41101...
# Processing 41102...
# Processing 41103...
# Event 41103 not found
# Processing 41104...
# Processing 41105...
# Processing 41106...
# Processing 41107...
# Processing 41108...
# Processing 41109...
# Processing 41110...
# Processing 41111...
# Event 41111 not found
# Processing 41112...
# Processing 41113...
# Processing 41114...
# Processing 41115...
# Event 41115 not found
# Processing 41116...
# Processing 41117...
# Processing 41118...
# Processing 41119...
# Event 41119 not found
# Processing 41120...
# Processing 41121...
# Processing 41122...
# Processing 41123...
# Processing 41124...
# Processing 41125...
# Processing 41126...
# Event 41126 not found
# Processing 41127...
# Processing 41128...
# Processing 41129...
# Processing 41130...
# Event 41130 not found
# Processing 41131...
# Processing 41132...
# Event 41132 not found
# Processing 41133...
# Event 41133 not found
# Processing 41134...
# Event 41134 not found
# Processing 41135...
# Event 41135 not found
# Processing 41136...
# Event 41136 not found
# Processing 41137...
# Event 41137 not found
# Processing 41138...
# Event 41138 not found
# Processing 41139...
# Event 41139 not found
# Processing 41140...
# Event 41140 not found
# Processing 41141...
# Event 41141 not found
# Processing 41142...
# Event 41142 not found
# Processing 41143...
# Event 41143 not found
# Processing 41144...
# Event 41144 not found
# Processing 41145...
# Event 41145 not found
# Processing 41146...
# Event 41146 not found
# Processing 41147...
# Event 41147 not found
# Processing 41148...
# Event 41148 not found
# Processing 41149...
# Event 41149 not found
# Processing 41150...
# Event 41150 not found
# Processing 41151...
# Event 41151 not found
# Processing 41152...
# Event 41152 not found
# Processing 41153...
# Event 41153 not found
# Processing 41154...
# Processing 41155...
# Processing 41156...
# Processing 41157...
# Processing 41158...
# Event 41158 not found
# Processing 41159...
# Event 41159 not found
# Processing 41160...
# Event 41160 not found
# Processing 41161...
# Processing 41162...
# Processing 41163...
# Processing 41164...
# Processing 41165...
# Processing 41166...
# Processing 41167...
# Processing 41168...
# Processing 41169...
# Processing 41170...
# Processing 41171...
# Processing 41172...
# Processing 41173...
# Processing 41174...
# Processing 41175...
# Processing 41176...
# Processing 41177...
# Processing 41178...
# Processing 41179...
# Processing 41180...
# Processing 41181...
# Processing 41182...
# Processing 41183...
# Processing 41184...
# Processing 41185...
# Processing 41186...
# Processing 41187...
# Processing 41188...
# Processing 41189...
# Processing 41190...
# Event 41190 not found
# Processing 41191...
# Processing 41192...
# Processing 41193...
# Event 41193 not found
# Processing 41194...
# Processing 41195...
# Event 41195 not found
# Processing 41196...
# Event 41196 not found
# Processing 41197...
# Event 41197 not found
# Processing 41198...
# Event 41198 not found
# Processing 41199...
# Event 41199 not found
# Processing 41200...
# Event 41200 not found
# Processing 41201...
# Event 41201 not found
# Processing 41202...
# Event 41202 not found
# Processing 41203...
# Processing 41204...
# Event 41204 not found
# Processing 41205...
# Processing 41206...
# Event 41206 not found
# Processing 41207...
# Processing 41208...
# Event 41208 not found
# Processing 41209...
# Event 41209 not found
# Processing 41210...
# Event 41210 not found
# Processing 41211...
# Event 41211 not found
# Processing 41212...
# Processing 41213...
# Event 41213 not found
# Processing 41214...
# Event 41214 not found
# Processing 41215...
# Event 41215 not found
# Processing 41216...
# Event 41216 not found
# Processing 41217...
# Processing 41218...
# Processing 41219...
# Processing 41220...
# Processing 41221...
# Processing 41222...
# Processing 41223...
# Processing 41224...
# Processing 41225...
# Processing 41226...
# Processing 41227...
# Event 41227 not found
# Processing 41228...
# Processing 41229...
# Processing 41230...
# Processing 41231...
# Processing 41232...
# Processing 41233...
# Processing 41234...
# Processing 41235...
# Event 41235 not found
# Processing 41236...
# Event 41236 not found
# Processing 41237...
# Event 41237 not found
# Processing 41238...
# Processing 41239...
# Processing 41240...
# Event 41240 not found
# Processing 41241...
# Event 41241 not found
# Processing 41242...
# Processing 41243...
# Processing 41244...
# Event 41244 not found
# Processing 41245...
# Event 41245 not found
# Processing 41246...
# Event 41246 not found
# Processing 41247...
# Event 41247 not found
# Processing 41248...
# Event 41248 not found
# Processing 41249...
# Event 41249 not found
# Processing 41250...
# Event 41250 not found
# Processing 41251...
# Processing 41252...
# Processing 41253...
# Processing 41254...
# Processing 41255...
# Processing 41256...
# Event 41256 not found
# Processing 41257...
# Processing 41258...
# Processing 41259...
# Processing 41260...
# Processing 41261...
# Processing 41262...
# Processing 41263...
# Processing 41264...
# Processing 41265...
# Processing 41266...
# Processing 41267...
# Processing 41268...
# Processing 41269...
# Processing 41270...
# Processing 41271...
# Processing 41272...
# Processing 41273...
# Event 41273 not found
# Processing 41274...
# Processing 41275...
# Event 41275 not found
# Processing 41276...
# Event 41276 not found
# Processing 41277...
# Processing 41278...
# Event 41278 not found
# Processing 41279...
# Event 41279 not found
# Processing 41280...
# Processing 41281...
# Processing 41282...
# Event 41282 not found
# Processing 41283...
# Processing 41284...
# Processing 41285...
# Processing 41286...
# Processing 41287...
# Processing 41288...
# Processing 41289...
# Event 41289 not found
# Processing 41290...
# Processing 41291...
# Event 41291 not found
# Processing 41292...
# Processing 41293...
# Processing 41294...
# Processing 41295...
# Processing 41296...
# Event 41296 not found
# Processing 41297...
# Processing 41298...
# Processing 41299...
# Processing 41300...
# Processing 41301...
# Event 41301 not found
# Processing 41302...
# Event 41302 not found
# Processing 41303...
# Event 41303 not found
# Processing 41304...
# Processing 41305...
# Processing 41306...
# Processing 41307...
# Processing 41308...
# Processing 41309...
# Event 41309 not found
# Processing 41310...
