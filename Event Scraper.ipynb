# %%
from id_converter import numeric_to_url_id
from retrieve_event_data import retrieve_event_data
import time

# North Carolina up through 30 April
target_ids = [41091,41734,42004,41710,41287,41004,40956]
# failed = 41082,41081,41080,41079,

for num_id in target_ids:
    url_id = numeric_to_url_id(num_id)
    print(f"Starting job for ID: {num_id}")
    
    # The function handles everything and creates the file
    retrieve_event_data(url_id)
    time.sleep(5)
# Out:
# Starting job for ID: 41091
# Connecting to AES Event API for ID: PTAwMDAwNDEwOTE90...
# --- 2026 AAU Rocky Mount Grand Prix and Boys ECPL | 9 Divisions ---
#
# Processing: 14 Boys
# Processing: 14 Club
# Processing: 15 Club
# Processing: 16 Boys Open
# Processing: 16 Boys Premier
# Processing: 16 Club
# Processing: 18 Boys Open
# Processing: 18 Boys Premier
# Processing: 18 Club
#
# 🎉 SUCCESS! Saved 325 unique competitive matches to 'Data/PTAwMDAwNDEwOTE90.csv'.
# Starting job for ID: 41734
# Connecting to AES Event API for ID: PTAwMDAwNDE3MzQ90...
# --- Locomotive Challenge 2026 | 8 Divisions ---
#
# Processing: 12U Girls
# Processing: 13U Girls
# Processing: 14U - 16U Boys
# Processing: 14U Girls
# Processing: 15U Girls
# Processing: 16U - 18U Boys
# Processing: 16U Girls
# Processing: 17/18U Girls
#
# 🎉 SUCCESS! Saved 328 unique competitive matches to 'Data/PTAwMDAwNDE3MzQ90.csv'.
# Starting job for ID: 42004
# Connecting to AES Event API for ID: PTAwMDAwNDIwMDQ90...
# ...
